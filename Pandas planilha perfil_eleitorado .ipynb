# %%
import pandas as pd

# %%
#abrindo e visualizando dados  
perfil_eleitorado = pd.read_csv(r"C:\Users\cauek\Downloads\database_desfio_renovaBR\eleitorado\perfil_eleitorado_2020\perfil_eleitorado_2020.csv", encoding="Latin-1", sep=";")
perfil_eleitorado
# Out:
#          DT_GERACAO HH_GERACAO  ANO_ELEICAO SG_UF  CD_MUNICIPIO
# 0        01/08/2020   08:37:48         2020    SP         70734  \
# 1        01/08/2020   08:37:48         2020    SP         70734
# 2        01/08/2020   08:37:48         2020    SP         70734
# 3        01/08/2020   08:37:48         2020    SP         70734
# 4        01/08/2020   08:37:48         2020    SP         70734
# ...             ...        ...          ...   ...           ...
# 4248502  01/08/2020   08:37:48         2020    PR         74349
# 4248503  01/08/2020   08:37:48         2020    PR         74349
# 4248504  01/08/2020   08:37:48         2020    PR         74349
# 4248505  01/08/2020   08:37:48         2020    PR         74349
# 4248506  01/08/2020   08:37:48         2020    PR         74349
#
#                  NM_MUNICIPIO  CD_MUN_SIT_BIOMETRIA DS_MUN_SIT_BIOMETRIA
# 0        SÃO BENTO DO SAPUCAÍ                     0        Sem biometria  \
# ...

# %%
#excluindo as linhas não referentes ao estado de SP
filtro_sp = "SP"
ocultar = perfil_eleitorado['SG_UF'] != filtro_sp
perfil_eleitorado = perfil_eleitorado[~ocultar]
perfil_eleitorado
# Out:
#          DT_GERACAO HH_GERACAO  ANO_ELEICAO SG_UF  CD_MUNICIPIO
# 0        01/08/2020   08:37:48         2020    SP         70734  \
# 1        01/08/2020   08:37:48         2020    SP         70734
# 2        01/08/2020   08:37:48         2020    SP         70734
# 3        01/08/2020   08:37:48         2020    SP         70734
# 4        01/08/2020   08:37:48         2020    SP         70734
# ...             ...        ...          ...   ...           ...
# 4248331  01/08/2020   08:37:48         2020    SP         72451
# 4248332  01/08/2020   08:37:48         2020    SP         72451
# 4248333  01/08/2020   08:37:48         2020    SP         72451
# 4248334  01/08/2020   08:37:48         2020    SP         72451
# 4248335  01/08/2020   08:37:48         2020    SP         72451
#
#                  NM_MUNICIPIO  CD_MUN_SIT_BIOMETRIA DS_MUN_SIT_BIOMETRIA
# 0        SÃO BENTO DO SAPUCAÍ                     0        Sem biometria  \
# ...

# %%
#excluindo as colunas que não serão utilizadas
colunas_a_excluir = ["DT_GERACAO",
                     "HH_GERACAO",
                     'ANO_ELEICAO',
                     "SG_UF",
                     "CD_MUN_SIT_BIOMETRIA",
                     "DS_MUN_SIT_BIOMETRIA",
                     "NR_ZONA",
                     "QT_ELEITORES_BIOMETRIA"]
perfil_eleitorado = perfil_eleitorado.drop(colunas_a_excluir, axis=1)
perfil_eleitorado
# Out:
#          CD_MUNICIPIO          NM_MUNICIPIO  CD_GENERO  DS_GENERO
# 0               70734  SÃO BENTO DO SAPUCAÍ          4   FEMININO  \
# 1               70734  SÃO BENTO DO SAPUCAÍ          4   FEMININO
# 2               70734  SÃO BENTO DO SAPUCAÍ          4   FEMININO
# 3               70734  SÃO BENTO DO SAPUCAÍ          4   FEMININO
# 4               70734  SÃO BENTO DO SAPUCAÍ          4   FEMININO
# ...               ...                   ...        ...        ...
# 4248331         72451           VOTUPORANGA          2  MASCULINO
# 4248332         72451           VOTUPORANGA          2  MASCULINO
# 4248333         72451           VOTUPORANGA          2  MASCULINO
# 4248334         72451           VOTUPORANGA          2  MASCULINO
# 4248335         72451           VOTUPORANGA          2  MASCULINO
#
#          CD_ESTADO_CIVIL DS_ESTADO_CIVIL  CD_FAIXA_ETARIA
# 0                      3          CASADO             7074  \
# ...

# %%
perfil_eleitorado.to_csv("PerfilEleitorado", sep=";")
